# %% [markdown]
# # Homework 2
#
# ## Chen Gengyang
#
# Instructions:
#
#  1. Please replace "Yourname" above, and in the title of this notebook.
#  2. Import all the libraries you end up using in the cell below. Please only use those libraries which we have used in class (i.e. nltk, collections, pandas, etc.).
#  3. Complete all the exercises, replacing "enter code here" with your code, and "enter markdown here" with your markdown. Annotate your code with markdown cells, to explain what you're doing, and interpret your results.
#  4. From the Kernel menu, select "restart and run all." This will help me to see the output of your answers.
#  5. Email me your completed notebook: jonathan.reeve@columbia.edu

# %%
import nltk
import pandas as pd
import collections
# %matplotlib inline

# %% [markdown]
# ### 1. Write a function that takes a text in English (i.e. a string), then computes the average number of words per sentence, for that text.

# %% [markdown]
# #### function: getAvgSentLength(section)
#
# use `nltk.sent_tokenize` to get all sentences, and then use `nltk.word_tokenize` to get all words in each sentence.
# Then compute the number of words in each sentence and the number of sentences.

# %%
def getAvgSentLength(section):
    ''' 
        This function computes the average number  of words per sentence of a text.
        Input: a string
        Output: a number(float) average number of words per sentence in that string.
    '''
    wordLengthList=[len(nltk.word_tokenize(sent)) for sent in nltk.sent_tokenize(section)]
    return round(sum(wordLengthList)/len(wordLengthList))

section="Chapter I\n\nIn the first part of ROBINSON CRUSOE, at page one hundred and\ntwenty-nine, you will find it thus written:\n\n“Now I saw, though too late, the Folly of beginning a Work before we\ncount the Cost, and before we judge rightly of our own Strength to go\nthrough with it.”\n\nOnly yesterday, I opened my ROBINSON CRUSOE at that place. Only this\nmorning (May twenty-first, Eighteen hundred and fifty), came my lady’s\nnephew, Mr. Franklin Blake, and held a short conversation with me, as\nfollows:–\n\n“Betteredge,” says Mr. Franklin, “I have been to the lawyer’s about some\nfamily matters; and, among other things, we have been talking of the\nloss of the Indian Diamond, in my aunt’s house in Yorkshire, two years\nsince. Mr. Bruff thinks as I think, that the whole story ought, in the\ninterests of truth, to be placed on record in writing–and the sooner the\nbetter.”\n\nNot perceiving his drift yet, and thinking it always desirable for the\nsake of peace and quietness to be on the lawyer’s side, I said I thought\nso too. Mr. Franklin went on.\n\n“In this matter of the Diamond,” he said, “the characters of innocent\npeople have suffered under suspicion already–as you know. The memories\nof innocent people may suffer, hereafter, for want of a record of the\nfacts to which those who come after us can appeal. There can be no doubt\nthat this strange family story of ours ought to be told. And I think,\nBetteredge, Mr. Bruff and I together have hit on the right way of\ntelling it.”\n\nVery satisfactory to both of them, no doubt. But I failed to see what I\nmyself had to do with it, so far.\n\n“We have certain events to relate,” Mr. Franklin proceeded; “and we have\ncertain persons concerned in those events who are capable of relating\nthem. Starting from these plain facts, the idea is that we should all\nwrite the story of the Moonstone in turn–as far as our own personal\nexperience extends, and no farther. We must begin by showing how the\nDiamond first fell into the hands of my uncle Herncastle, when he was\nserving in India fifty years since. This prefatory narrative I have\nalready got by me in the form of an old family paper, which relates the\nnecessary particulars on the authority of an eye-witness. The next thing\nto do is to tell how the Diamond found its way into my aunt’s house in\nYorkshire, two years ago, and how it came to be lost in little more than\ntwelve hours afterwards. Nobody knows as much as you do, Betteredge,\nabout what went on in the house at that time. So you must take the pen\nin hand, and start the story.”\n\nIn those terms I was informed of what my personal concern was with the\nmatter of the Diamond. If you are curious to know what course I took\nunder the circumstances, I beg to inform you that I did what you would\nprobably have done in my place. I modestly declared myself to be quite\nunequal to the task imposed upon me–and I privately felt, all the time,\nthat I was quite clever enough to perform it, if I only gave my own\nabilities a fair chance. Mr. Franklin, I imagine, must have seen my\nprivate sentiments in my face. He declined to believe in my modesty; and\nhe insisted on giving my abilities a fair chance.\n\nTwo hours have passed since Mr. Franklin left me. As soon as his back\nwas turned, I went to my writing desk to start the story. There I have\nsat helpless (in spite of my abilities) ever since; seeing what Robinson\nCrusoe saw, as quoted above–namely, the folly of beginning a work before\nwe count the cost, and before we judge rightly of our own strength to go\nthrough with it. Please to remember, I opened the book by accident, at\nthat bit, only the day before I rashly undertook the business now in\nhand; and, allow me to ask–if THAT isn’t prophecy, what is?\n\nI am not superstitious; I have read a heap of books in my time; I am a\nscholar in my own way. Though turned seventy, I possess an active\nmemory, and legs to correspond. You are not to take it, if you please,\nas the saying of an ignorant man, when I express my opinion that such a\nbook as ROBINSON CRUSOE never was written, and never will be written\nagain. I have tried that book for years–generally in combination with a\npipe of tobacco–and I have found it my friend in need in all the\nnecessities of this mortal life. When my spirits are bad–ROBINSON\nCRUSOE. When I want advice–ROBINSON CRUSOE. In past times when my wife\nplagued me; in present times when I have had a drop too much–ROBINSON\nCRUSOE. I have worn out six stout ROBINSON CRUSOES with hard work in my\nservice. On my lady’s last birthday she gave me a seventh. I took a drop\ntoo much on the strength of it; and ROBINSON CRUSOE put me right again.\nPrice four shillings and sixpence, bound in blue, with a picture into\nthe bargain.\n\nStill, this don’t look much like starting the story of the Diamond–does\nit? I seem to be wandering off in search of Lord knows what, Lord knows\nwhere. We will take a new sheet of paper, if you please, and begin over\nagain, with my best respects to you.\n'"
print(getAvgSentLength(section))
# Out:
# 28

# %% [markdown]
# ### 2. Use your function to calculate the average sentence length for all the narrators we have read so far (Betteredge, Clack, Bruff, Blake). Then, in a markdown cell, describe what you think this might indicate.

# %%
moonStone=open('moonstone.md').read()
moonParts=moonStone.split('\n## ')
bet, clack, bruff, blake = [moonParts[i] for i in [2,4,5,6]]
for item in list(zip(['bet','clack','bruff','blake'],[bet,clack,bruff,blake])):
    narrator=item[0]
    avgSentLength=getAvgSentLength(item[1])
    print("{:10} {:3}".format(narrator,avgSentLength))
# Out:
# bet         25
# clack       22
# bruff       27
# blake       24

# %% [markdown]
# ##### Bruff
# The average sentence length of Bruff is longest. As a lawyer, he likes to narrate in long and precise sentences. Even in the dialogue, he repeats the other person's words in a different way. This is in line with the professional characteristics of lawyers.
# ##### Betteredge
# Then comes with Betteredge. 25 is also more than average of the sentence length. Since Betteregde is over 80, it's consist with the elderly's habit of speaking, let alone Betteredge is always calm.
# ##### Blake
# He is around the average. However, his narrative contains a lot of short dialugue, which is likely to have effects on analyzing this character by the data.
# ##### Clack
# The average sentence length of Miss Clack is shortest. She lookes like an emotional young lady who always expresses her strong feelings in short sentences, and she does.

# %% [markdown]
# ### 3. Choose a motif that you notice in _The Moonstone_. Choose around 3-5 words (or tokens, stems, or lemmas) that you think represent this motif. Create a plot to show the positions of these words in the narrative time of _The Moonstone_ (at least the amount that we've read of it). Then create concordances for a few of these words. Finally, in 2-3 paragraphs of well-formatted markdown, describe what this tells you about how the motif operates in the novel.

# %%
def cleanAndTokenize(text):
    narrReplaced = text.lower()
    for mark in ["–", '-', '*']:
        narrReplaced = narrReplaced.replace(mark, ' ')
    tokens = nltk.word_tokenize(narrReplaced)
    return tokens

motif="addiction"
tokens=["cigar","tobacco","brandy","opium","laudanum","christian"]
text=nltk.Text(cleanAndTokenize(moonStone))

text.dispersion_plot(tokens)
print('concordances of "brandy":')
text.concordance('brandy')
print('concordances of "laudanum":')
text.concordance('laudanum')
print('\nconcordances of "christian":')
text.concordance('christian')
# Out:
# concordances of "brandy":
# Displaying 14 of 14 matches:
# king room , with the soda water and brandy , and found that miss rachel had pu
# the side table , presiding over the brandy and soda water . my lady and miss r
# wo gentlemen . mr. godfrey had some brandy and soda water , mr. franklin took
# ured to advise his having a drop of brandy and water , by way of night cap . m
#  at all . mr. franklin declined the brandy and water , and went up stairs with
#  called down to me . “ send up some brandy and water into my room. ” i sent up
# y room. ” i sent up samuel with the brandy and water ; and then went out and u
#  we persuaded you to have a drop of brandy and water to cheer you up a little.
# u up a little. ” “ i am not used to brandy and water . it is quite possible— ”
# i was for giving him champagne , or brandy , ammonia , and quinine . a serious
# ything . when wine failed , i tried brandy . when the other stimulants lost th
# ...

# %% [markdown]
# #### **Addiction of various sorts appears in The Moonstone. **
# * **Franklin Blake and Gabriel Betteredge: Tobacco **<br>
# Although the tobacco-related words don't appear particularly frequently in the picture above, they do have a lot to do with the story. The moonstone's disappearance is the direct result of opium and his addiction to cigarettes. The importance of laudanum in the moonstone plot can hardly be ignored, as the whole mystery of the missing moonstone revolves around the opioid taken by Franklin Blake. This mystery, happening specifically because Franklin takes laudanum without knowing it, is solved by the laudanum addict Ezra Jennings as well. Jennings drugs franklin again, allowing him to recreat the night of the robbery in the opium doze, to solve the mystery. Thus, opium enables both the theft and the solving of the theft of the Moonstone.
# * **Ezra Jennings and John Herncastle: Opium **<br>
# The story doesn't talk much about John Herncastle, but the fact that He is an opium addict is clear to the readers.<br>
# As is shown in the picture above, `opium` and `laudanum` are frequently used in the second half of the story, especially in Jenning's narrative. In addition to using opium to recreate the night of the theft, he is also heavily involved in laudanum.
# The life of Ezra Jennings is tragic. Expect that his strange apperance contributes to his tragedy, his addiction to opium has something to with it as well. Jennings' opium addiction is related to his status as a part-colonial subject (opium having originated in the East). Also, by the end of the novel, Jennings dies of the disease he has staved off using opium for years.
# * **Miss Clack: Christian**<br>
# Miss Clack is addicted to the distribution of her Christian pamphlets, as this action is presented as something that Miss Clack requires to make her feel normal and satisfied. In her narrative, `christian` and the concerning words appear far more frequently than in others' narratives.

# %%
# anwser
# motif is something like the theme.
# like drug, roses
moonstoneTokens=nltk.word_tokenize(moonStone.lower())
moonstoneText=nltk.Text(moonstoneTokens)
moonstoneText.dispersion_plot(['truth'])

# %%
moonstoneText.dispersion_plot(['water','light','dark','superstition','moon','moonstone'])

# %%
moonstoneText.dispersion_plot(['opium','tobacco','brandy'])

# %%
moonstoneText.dispersion_plot(['spring','summer','fall','autumn','winter'])

# %%
moonstoneText.dispersion_plot(['death','murder','kill','autumn','winter'])

# %%
# moonstoneText.concordance(text) [text for text in ['spring','summer','fall','autumn','winter']]

# %%
import numpy as np
opiumCounts=[1 if token=='christian' else 0 for token in moonstoneTokens]
opiumSeries=pd.Series(opiumCounts)
opiumBins=[np.sum(item) for item in np.array_split(np.array(opiumCounts),100)]
pd.Series(opiumBins).plot()

# %% [markdown]
# ### 4. Find the distinctive words of Ezra Jennings' narrative (what we're reading for Monday). Discuss these words, and your interpretation of them. Can you hear Jennings's personality come through in these? Why or why not?

# %%
bet, clack, bruff, blake, jennings = [moonParts[i] for i in [2,4,5,6,7]]
allNarrators=[bet, clack, bruff, blake, jennings]
allTokens=[cleanAndTokenize(text) for text in allNarrators]

narrCounts=[]
for narr in allTokens:
    narrCounts.append(collections.Counter(narr))
    
narrCountsDF=pd.DataFrame(narrCounts,index=["bet","clack","bruff","blake","jennings"]).fillna(0).T
totalNumTokensForNarrators = [len(tokensForNarrator) for tokensForNarrator in allTokens]

proportions = narrCountsDF / totalNumTokensForNarrators
proportions['average'] = proportions.mean(axis=1)
proportions['jenningsness'] = proportions['jennings'] - proportions['average']
proportions.sort_values('jenningsness', ascending=False)
# Out:
#                  bet     clack     bruff     blake  jennings   average  \
# .           0.035973  0.037768  0.033671  0.036579  0.043629  0.037524
# he          0.008564  0.008081  0.008745  0.007115  0.013993  0.009300
# the         0.050683  0.043754  0.055083  0.049465  0.054721  0.050741
# blake       0.000583  0.000762  0.000899  0.001003  0.005063  0.001662
# mr.         0.006542  0.006639  0.007437  0.005034  0.010125  0.007156
# him         0.004032  0.003592  0.005149  0.002990  0.007395  0.004631
# betteredge  0.001375  0.000054  0.000163  0.002365  0.004096  0.001611
# is          0.003969  0.005170  0.004005  0.004579  0.007452  0.005035
# room        0.001313  0.002068  0.000654  0.001533  0.003868  0.001887
# to          0.028389  0.029632  0.032118  0.030902  0.032480  0.030704
# last        0.001073  0.000490  0.000899  0.001098  0.002901  0.001292
# his         0.005928  0.005605  0.007682  0.005015  0.007964  0.006439
# ...

# %% [markdown]
# 1. `.` ranks first in the list. Although it isn't a word, it implies that Jenning is a calm narrator. Exactly, Jennings is an aspiring doctor and researcher. He meticulously uses respected sources and experimental techniques to prove Franklin Blake's innocence.
# 2. In Jennings's distinctive words, there are a lot of names, such as `blake`, `betteredge`, `jennings`, `bruff`, `verinder` and `merridew`. Also, it's worth mentioning that `mr.` also ranks high. Maybe he is humble, even a little humble. His strange appearance seems to define him for others and encourage their social rejection of him. From the content of the article, in the beginning narrative Jennings shows great appreciate for Franklin and Rachel on account of the kindness and respect they show him. What a poor man!
# 3. Words such as `opium` and `medicine` hint his job. It can also be inferred that he has the typical personality of a doctor like caring, compassionate, kind and so on.

# %% [markdown]
# ### 5. Write a program to determine whose name appears in the most number of paragraphs with the words "moonstone" and "diamond." Then, in a markdown cell, describe anything you might notice about your results.
#
# Here's one way you might do this:
#  - Make a list of all names we've encountered in the novel so far. (Be careful to include both "Rachel" and "Miss Verinder," for instance.)
#  - Break the novel into paragraphs by splitting on double line breaks (`\n\n`).
#  - Tokenize each paragraph.
#  - Test for the presence of a word using the `in` keyword for lists.
#  - Maintain a dictionary for each character, where the key is the character's name, and the value is a tally of how many times their name has appeared in the same paragraph as "moonstone" and "diamond."

# %%
# nameList=['Rachel Verinder','Franklin Blake','Godfrey Ablewhite','Gabriel Betteredge','Ezra Jennings','Rosanna Spearman','Septimus Luker','Sergeant Cuff','Mathew Bruff']
auxNameList=['rachel','missverinder','mr.blake','franklin','godfrey','betteredge','ezrajennings','rosanna','luker',
             'cuff','bruff']

# allParas is a list(paragraphs) of a string(lowcase words in one paragraph)
allParas=[para for para in moonStone.split('\n\n')]
for paraIndex in range(len(allParas)):
    allParas[paraIndex]=''.join(cleanAndTokenize(allParas[paraIndex]))

# filter the paragraphs with "moonstone" and "diamond"
moonParas=list(filter(lambda para:('moonstone' in para) or ('diamond' in para),allParas))

auxDict={}
for name in auxNameList:
    auxDict[name]=sum([moonPara.count(name) for moonPara in moonParas])
    
print('The number of paragraphs with the words "moonstone" and "diamond":', len(moonParas))
print(sorted(auxDict.items(), key=lambda d: d[1], reverse=True))
# Out:
# The number of paragraphs with the words "moonstone" and "diamond": 362
# [('franklin', 121), ('rachel', 109), ('rosanna', 55), ('betteredge', 52), ('missverinder', 39), ('luker', 39), ('godfrey', 37), ('mr.blake', 35), ('bruff', 34), ('cuff', 23), ('ezrajennings', 7)]

# %% [markdown]
# ***Franklin Blake*** appears 156 times, which is the sum of "franklin" and "mr.blake".<br>
# ***Rachel Verinder*** appears 148 times, which is the sum of "rachel" and "missverinder".<br>
# There are 362 paragraphs which appear "moonstone" and "diamond", and these two people have something to do with most of these paragraphs.
# It's not surprising since they are the key characters. <br>
# However, it surprises me that ***Spetimus Luker*** appears 39 times, which is the third frequent. It seems that he is just a seedy London moneylender and doesn't have much to do with the main plot, but think carefully about the storyline, I found that everytime "Moonstone" appears, there is always his shadow, no matter in Lady Verinder’s house or in London. Perphas it's the importance of a minor character that is to promote the development of the plot.<br>
# Also, as the one who actually stole the moonstone, ***Godfrey Ablewhite*** doesn't show up as many times as I think. Because of this, no one casts a suspicious eye on him at the beginning of the story. This enhances the twists of the plot.

# %%
# answer

# Make a list of all names we've encountered in the novel so far. 
# (Be careful to include both "Rachel" and "Miss Verinder," for instance.)
women=['Rachel Verrinder','Drusilla Clack']
titleAndLast=['Miss ' +name.split()[1] for name in women]
titleAndFirst=['Miss '+name.split()[0] for name in women]
women+titleAndLast+titleAndFirst
# Out:
# ['Rachel Verrinder',
#  'Drusilla Clack',
#  'Miss Verrinder',
#  'Miss Clack',
#  'Miss Rachel',
#  'Miss Drusilla']

# %% [markdown]
# ### 6. Write a program to determine the words that occur more often in sentences ending in exclamation marks. In a markdown cell, describe anything you notice in your results.
#
# Here's one way you might do this:
#
#  - Sentence-tokenize the novel.
#  - Make two empty lists, one for exclamation-mark sentences, and one for other sentences.
#  - Write a `for` loop to go through each sentence, and append it to one of the two lists, depending on whether it contains an exclamation mark.
#  - Join the lists together, using `" ".join(list)`, so that they're easier to word-tokenize.
#  - Word-tokenize each string.
#  - Make `Counter()` objects for the resulting list of word-tokens.
#  - Subtract one set of numbers from the other, to find the words that occur much more in one category than another.
#  - Sort the results according to the difference in frequencies between the two.

# %%
pd.set_option("display.max_rows", 100)

sents=nltk.sent_tokenize(moonStone)

exclamations,commonSents=[],[]
test=[]
for sent in sents:
    if "!" in sent:
        exclamations.append(sent)
    else:
        commonSents.append(sent)

wordsInExclamations=cleanAndTokenize(' '.join(exclamations))
wordsInCommonSents=cleanAndTokenize(' '.join(commonSents))

wordCounts=[collections.Counter(wordsInExclamations),collections.Counter(wordsInCommonSents)]
numOfWords=[len(wordsInExclamations),len(wordsInCommonSents)]
proportionDF=pd.DataFrame(wordCounts,index=['exclamation','common sent']).fillna(0).T/numOfWords
proportionDF['compare']=proportionDF['exclamation']-proportionDF['common sent']
proportionDF.sort_values('compare',ascending=False)
# Out:
#             exclamation  common sent   compare
# !              0.044452     0.000000  0.044452
# ”              0.026976     0.011452  0.015525
# “              0.024691     0.011690  0.013001
# ’              0.015594     0.010253  0.005341
# you            0.014519     0.010010  0.004508
# i              0.027379     0.024825  0.002554
# oh             0.002599     0.000047  0.002552
# t              0.004929     0.002454  0.002476
# said           0.005332     0.003442  0.001890
# if             0.004660     0.002887  0.001773
# how            0.002599     0.000998  0.001601
# here           0.002509     0.000961  0.001548
# there          0.003630     0.002230  0.001400
# don            0.002151     0.000840  0.001311
# me             0.009231     0.007953  0.001278
# out            0.003809     0.002556  0.001253
# says           0.001837     0.000592  0.001245
# come           0.001837     0.000718  0.001119
# s              0.007394     0.006279  0.001115
# ...

# %% [markdown]
# * `!` ranks the top and `.` ranks last.
# * `“` and `”` appear more frequently in the exclamation-mark sentences than in other sentences. It shows that exclamation occurs more in dialogues.
# * The frequence of `don` and `t` is high. At the same time, there is more `’` than `‘`. And these parts make the word `don't`, which imples that people are more likely to use negative sentences when they are emotionally excited.
# * The data shows that `oh`, `how`, `god`, `dear`, `lord` and `ah`  appear frequently. This is in line with the habit of expressing exclamation in real life.
# * Two names, which are `betteredge` and `rachel`, appear in the first half of the list. I felt confused about this, so I picked up several sentences to explore the reason with the following program. Then I figured it out.<br> Although ***Betteredge*** is a calm old housekeeper, he, a witness to the first half of the investigation, is always surrounded by those emotional people involved in the case. In the search for the truth, those people always shout his name to express their own strong feelings in the dialogue.<br>
# It's totally different from ***Rachel***. In the first narrative, Rachel flips out for witnessing Franklin's theft. Therefore, the exclamatory sentences are uttered by her, and the narrator mentioned her name to describe the plot.

# %%
exclamationBet=[]
exclamationRachel=[]
for sent in sents:
    if "!" in sent:
        if "Betteredge" in sent:
            exclamationBet.append(sent)
        if "Rachel" in sent:
            exclamationRachel.append(sent)
print("Betteredge:")
print('\n'.join([str(i)+'.'+exclamationBet[i] for i in range(10)]))
print("Rachel:")
print('\n'.join([str(i)+'.'+exclamationRachel[i] for i in range(10)]))
# Out:
# Betteredge:
# 0.Let me
# alone, Mr. Betteredge!”
#
# The person here mentioned as Rosanna was our second housemaid.
# 1.“But the place shows,
# Mr. Betteredge–the place shows!”
#
# A remark which takes a man unawares by means of his own coat is not an
# easy remark to answer.
# 2.“You’re late for dinner, Rosanna–and I have come
# to fetch you in.”
#
# “You, Mr. Betteredge!” says she.
# 3.Sometimes,” says
# she in a low voice, as if she was frightened at her own fancy,
# “sometimes, Mr. Betteredge, I think that my grave is waiting for me
# here.”
#
# “There’s roast mutton and suet-pudding waiting for you!” says I.
# 4.Throw a
# stone in, Mr. Betteredge!
# 5.“Betteredge!” cries the voice, “where are you?” “Here!” I
# shouted out in return, without a notion in my mind of who it was.
# 6.“Dear old Betteredge!” says he.
# 7.And ‘this,’ Betteredge,
# means my uncle Herncastle’s famous Diamond.”
#
# “Good Lord, sir!” I broke out, “how do you come to be in charge of the
# ...

# %%
withEx=[sent for sent in nltk.sent_tokenize(moonStone) if sent.endswith("!")]
withoutEx=[sent for sent in nltk.sent_tokenize(moonStone) if not sent.endswith("!")]
withTokens=nltk.word_tokenize(' '.join(withEx))
withTokens=nltk.word_tokenize(' '.join(withoutEx))

# %% [markdown]
# ### Bonus: Write a program to determine the words that occur more often in parenthetical expressions. What do you notice about these words?

# %%
# get all parenthetical expressions
auxList=[part for part in moonStone.split('(') if ')' in part]
resList=[part.split(')')[0] for part in auxList]

# get the word token list of parenthetical expressions and the word tokens of sentences without parentheses.
parentheticalWordTokens=nltk.word_tokenize(' '.join(resList))
commonWordTokens=nltk.word_tokenize(' '.join([sent for sent in nltk.sent_tokenize(moonStone) if '(' not in sent]))

wordCounts=[collections.Counter(parentheticalWordTokens),collections.Counter(commonWordTokens)]
numOfWords=[len(parentheticalWordTokens),len(commonWordTokens)]

pd.set_option("display.max_rows", 30)
proportionDF=pd.DataFrame(wordCounts,index=['parenthetical','common']).fillna(0).T/numOfWords
proportionDF['compare']=proportionDF['parenthetical']-proportionDF['common']
proportionDF.sort_values('compare',ascending=False)
# Out:
#        parenthetical    common   compare
# as          0.025726  0.006848  0.018878
# of          0.029046  0.023488  0.005558
# if          0.007192  0.001924  0.005268
# in          0.021300  0.016086  0.005215
# which       0.008299  0.004095  0.004204
# to          0.032642  0.028929  0.003713
# a           0.017704  0.014190  0.003514
# !           0.007746  0.004412  0.003334
# is          0.007192  0.004104  0.003088
# I           0.028492  0.025542  0.002950
# with        0.008852  0.005991  0.002861
# or          0.004149  0.001542  0.002607
# who         0.003873  0.001267  0.002606
# under       0.003043  0.000601  0.002442
# no          0.004149  0.001849  0.002300
# ...              ...       ...       ...
# me          0.006086  0.008026 -0.001941
# his         0.003873  0.005879 -0.002006
# It          0.000000  0.002026 -0.002026
# He          0.000000  0.002464 -0.002464
# ;           0.001383  0.003908 -0.002525
# was         0.007469  0.010020 -0.002551
# ...

# %% [markdown]
# #### as
# I create concordances for `as` in the following cell and have some foundings:
# * Add some information of time, address or characters in the situation at that point.
# * Make some explanations about the reasons for the action in the last sentence.
# * Psychological description of the narrator, such as `as I guessed`, `as I suppose` and `as I thought`.
#
# #### of, in, which, to, is, with, who
# These are frequently used to make explanations.
#
# #### if
# 1. The narrators often use `if` in parenthetical expressions to make assumptions.
# > She had turned (if Penelope was to be believed) all the colours of the rainbow.
# 2. Sometimes the narrators talk to the readers, which also convey to the reader some information about their own attitudes towards the character or the plot.
# > One of them (if you will pardon my mentioning it) was never keeping to the matter in hand.
# 3. Supplement secondary information.
# >“Drusilla,” she said (if I have not already mentioned that my Christian name is Drusilla, permit me to mention it now), “you are touching quite innocently, I know–on a very distressing subject.”
# 4. It seems that the narrators also use `if` to talk to themselves, like self-talks, expressing their feelings.
# >Sergeant Cuff looked at me. I made a step forward to speak to my mistress–and, feeling my heart fail me (if I must own it), took a step back again, and said nothing.

# %%
nltk.Text(parentheticalWordTokens).concordance('as')
# Out:
# Displaying 25 of 93 matches:
# 1799 as in India carrying its curse with it i
# e such an expression by their dress , as I guessed , officers of the palace un
# sion page one hundred and fifty-eight as I remember him seven hundred a year a
# s I remember him seven hundred a year as he used to put it himself saving your
# nelope ’ s next words stirred me up . as we afterwards discovered with a view
# letter from him at the appointed date as I thought before he recovered the tra
# ch I have often seen done in the East as you know as I supposed as well as I c
# ten seen done in the East as you know as I supposed as well as I could make ou
# in the East as you know as I supposed as well as I could make out before he be
# ast as you know as I supposed as well as I could make out before he began to t
#  the bank there . God bless it ! just as her late mother used to get in my way
# sbelieve ladies , I am sorry to say , as well as gentlemen led by me for reaso
# ...

# %%
nltk.Text(parentheticalWordTokens).concordance('if')
# Out:
# Displaying 25 of 26 matches:
# s in India carrying its curse with it if I may use such an expression by their
# y man , high or low , I ever met with if I may use such an expression page one
# e key of the late Sir John ’ s cellar if the truth must be owned NOTA BENE : W
# he had done being a Christian woman , if ever there was one yet which was most
# ch was most unjust at my time of life if you will pardon my mentioning it to g
# r used to get in my way on the stairs if Penelope was to be believed and no do
#  of fashion latterly in the gay world if you will pardon me the expression to
# is time provided you can scratch me , if I scratch you on a small independence
# ! There was a woman in ten thousand , if you like ! as I have since thought as
# s to what your state of mind would be if I reported her in her native tongue .
# Rosanna in spite of my calling to him if I must own it which you will find Mis
# ...
